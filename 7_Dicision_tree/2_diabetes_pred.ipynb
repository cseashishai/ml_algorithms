# %% [markdown]
# ## Diabetes Predection

# %%
from sklearn.datasets import load_diabetes

# %%
dataset =load_diabetes()

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
import pandas as pd
df_diabetes=pd.DataFrame(dataset.data,columns=[
    'age',
    'sex',  
    'bmi',     
    'bp',      
    's1',      
    's2',      
    's3',      
    's4',      
    's5',      
    's6'      
])
df_diabetes.tail(10)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 432  0.009016 -0.044642  0.055229 -0.005670  0.057597  0.044719 -0.002903
# 433 -0.027310 -0.044642 -0.060097 -0.029770  0.046589  0.019980  0.122273
# 434  0.016281 -0.044642  0.001339  0.008101  0.005311  0.010899  0.030232
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 436 -0.056370 -0.044642 -0.074108 -0.050427 -0.024960 -0.047034  0.092820
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 432  0.023239  0.055686  0.106617
# 433 -0.039493 -0.051404 -0.009362
# 434 -0.039493 -0.045424  0.032059
# ...

# %%
## Independed and depended Features 
X= df_diabetes
y=dataset['target']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 106 -0.096328 -0.044642 -0.076264 -0.043542 -0.045599 -0.034821  0.008142
# 270  0.005383  0.050680  0.030440  0.083844 -0.037344 -0.047347  0.015505
# 348  0.030811 -0.044642 -0.020218 -0.005670 -0.004321 -0.029497  0.078093
# 435 -0.012780 -0.044642 -0.023451 -0.040099 -0.016704  0.004636 -0.017629
# 102 -0.092695 -0.044642  0.028284 -0.015999  0.036958  0.024991  0.056003
#
#            s4        s5        s6
# 106 -0.039493 -0.059471 -0.083920
# 270 -0.039493  0.008641  0.015491
# 348 -0.039493 -0.010903 -0.001078
# 435 -0.002592 -0.038460 -0.038357
# 102 -0.039493 -0.005142 -0.001078

# %%
# correletion
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.136522  0.181976  0.308406  0.261534  0.200301 -0.023100
# sex  0.136522  1.000000  0.044746  0.165128  0.033717  0.128023 -0.344052
# bmi  0.181976  0.044746  1.000000  0.384534  0.246802  0.255519 -0.372335
# bp   0.308406  0.165128  0.384534  1.000000  0.242052  0.164355 -0.113747
# s1   0.261534  0.033717  0.246802  0.242052  1.000000  0.891476  0.044128
# s2   0.200301  0.128023  0.255519  0.164355  0.891476  1.000000 -0.190767
# s3  -0.023100 -0.344052 -0.372335 -0.113747  0.044128 -0.190767  1.000000
# s4   0.165340  0.320619  0.431946  0.209316  0.556987  0.653120 -0.732862
# s5   0.270981  0.121299  0.448657  0.362476  0.528922  0.307541 -0.388778
# s6   0.262201  0.159936  0.394699  0.376421  0.323666  0.298647 -0.304091
#
#            s4        s5        s6
# age  0.165340  0.270981  0.262201
# sex  0.320619  0.121299  0.159936
# bmi  0.431946  0.448657  0.394699
# ...

# %%
# by using the heat map to visulize
import seaborn as sns
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor =DecisionTreeRegressor()
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings('ignore')


parms={
    'criterion':["squared_error","friedman_mse","absolute_error"], # Selecting The Node
    'splitter':['best','random'], 
    'max_depth':[1,2,3,4,5,10,15,25], ## Lenth of tree
    'max_features':['sqrt','log2',None] # To chek fasta + accuracy
}

# %%
new_regressor = DecisionTreeRegressor(random_state=42)

# %%
grid=GridSearchCV(regressor,param_grid=parms,cv=5,scoring='neg_mean_squared_error')

# %%
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 25],
#                          'max_features': ['sqrt', 'log2', None],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
y_pred=grid.predict(X_test)

# %%
grid.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'splitter': 'best'}

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
print(r2_score(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.3300178400000161
# 46.95762961834377
# 3616.769894653006

# %%
selectmodel = DecisionTreeRegressor(criterion='friedman_mse',max_depth=4,max_features='log2',splitter='best')

# %%
selectmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=4,
#                       max_features='log2')

# %%
## Now we visualizing the
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(selectmodel,filled=True)
# Out:
# [Text(0.5, 0.9, 'x[7] <= -0.014\nfriedman_mse = 6148.282\nsamples = 309\nvalue = 153.903'),
#  Text(0.25, 0.7, 'x[1] <= 0.003\nfriedman_mse = 3904.783\nsamples = 122\nvalue = 113.656'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'x[2] <= 0.006\nfriedman_mse = 4125.44\nsamples = 84\nvalue = 123.155'),
#  Text(0.0625, 0.3, 'x[8] <= 0.015\nfriedman_mse = 2626.578\nsamples = 65\nvalue = 107.231'),
#  Text(0.03125, 0.1, 'friedman_mse = 2201.181\nsamples = 60\nvalue = 100.55'),
#  Text(0.09375, 0.1, 'friedman_mse = 768.64\nsamples = 5\nvalue = 187.4'),
#  Text(0.1875, 0.3, 'x[9] <= 0.001\nfriedman_mse = 5417.917\nsamples = 19\nvalue = 177.632'),
#  Text(0.15625, 0.1, 'friedman_mse = 4765.716\nsamples = 13\nvalue = 202.231'),
#  Text(0.21875, 0.1, 'friedman_mse = 2679.222\nsamples = 6\nvalue = 124.333'),
#  Text(0.375, 0.5, 'x[6] <= -0.019\nfriedman_mse = 2776.646\nsamples = 38\nvalue = 92.658'),
# ...
